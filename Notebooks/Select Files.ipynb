# %%
# %sql
use catalog ushealthcaredynamics;
use schema bronze;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS ushealthcaredynamics.bronze.Ushealthcaredynamics
LOCATION 'abfss://ushealthcare@parkaru16sa.dfs.core.windows.net/volumes/Ushealthcaredynamics';

# %%
# %sql
SHOW VOLUMES;

# %%
# %fs ls '/Volumes/ushealthcaredynamics/bronze/ushealthcaredynamics/Datasets'
